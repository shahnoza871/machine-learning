# %%
# import pandas and load dataset
import pandas as pd
df = pd.read_csv(filepath_or_buffer="adult.data.csv")

# %%
# display first 5 rows of dataframe
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
# count number of males and females

df["sex"].value_counts()
# Out:
# sex
# Male      21790
# Female    10771
# Name: count, dtype: int64

# %%
# summary statistics for female entries

df[df["sex"]=="Female"].describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  10771.000000  1.077100e+04   10771.000000  10771.000000  10771.000000
# mean      36.858230  1.857463e+05      10.035744    568.410547     61.187633
# std       14.013697  1.029861e+05       2.379954   4924.262944    340.907518
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       25.000000  1.173630e+05       9.000000      0.000000      0.000000
# 50%       35.000000  1.760770e+05      10.000000      0.000000      0.000000
# 75%       46.000000  2.283315e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    10771.000000
# mean        36.410361
# std         11.811300
# min          1.000000
# 25%         30.000000
# 50%         40.000000
# 75%         40.000000
# max         99.000000

# %%
# summary statistics for all data

df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
# calculate percentage of entries from germany

isGermany= df[df["native-country"]=="Germany"].count()
print(isGermany["age"]*100/df.count()["age"])
# Out:
# 0.42074874850281013

# %%
# stats for entries with salary over 50k

df[df["salary"]==">50K"].describe()
# Out:
#                age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  7841.000000  7.841000e+03    7841.000000   7841.000000   7841.000000
# mean     44.249841  1.880050e+05      11.611657   4006.142456    195.001530
# std      10.519028  1.025418e+05       2.385129  14570.378951    595.487574
# min      19.000000  1.487800e+04       2.000000      0.000000      0.000000
# 25%      36.000000  1.191010e+05      10.000000      0.000000      0.000000
# 50%      44.000000  1.761010e+05      12.000000      0.000000      0.000000
# 75%      51.000000  2.309590e+05      13.000000      0.000000      0.000000
# max      90.000000  1.226583e+06      16.000000  99999.000000   3683.000000
#
#        hours-per-week
# count     7841.000000
# mean        45.473026
# std         11.012971
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         50.000000
# max         99.000000

# %%
# stats for entries with salary 50k or less

df[df["salary"]=="<=50K"].describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  24720.000000  2.472000e+04   24720.000000  24720.000000  24720.000000
# mean      36.783738  1.903409e+05       9.595065    148.752468     53.142921
# std       14.020088  1.064823e+05       2.436147    963.139307    310.755769
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       25.000000  1.176060e+05       9.000000      0.000000      0.000000
# 50%       34.000000  1.794650e+05       9.000000      0.000000      0.000000
# 75%       46.000000  2.390230e+05      10.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  41310.000000   4356.000000
#
#        hours-per-week
# count    24720.000000
# mean        38.840210
# std         12.318995
# min          1.000000
# 25%         35.000000
# 50%         40.000000
# 75%         40.000000
# max         99.000000

# %%
# filter entries with education level hs-grad or higher

df[df["salary"]==">50K"]["education"]>="HS-grad"
# Out:
# 7         True
# 8         True
# 9        False
# 10        True
# 11       False
#          ...
# 32539    False
# 32545    False
# 32554     True
# 32557     True
# 32560     True
# Name: education, Length: 7841, dtype: bool

# %%
df[df["race"]=="Amer-Indian-Eskimo"].describe()
# Out:
#               age         fnlwgt  education-num  capital-gain  capital-loss  \
# count  311.000000     311.000000     311.000000    311.000000    311.000000
# mean    37.173633  120831.147910       9.311897    625.266881     34.176849
# std     12.447130   88338.636336       2.310387   2753.238961    245.583106
# min     17.000000   12285.000000       2.000000      0.000000      0.000000
# 25%     28.000000   35036.500000       9.000000      0.000000      0.000000
# 50%     35.000000  102541.000000       9.000000      0.000000      0.000000
# 75%     45.500000  176142.000000      10.000000      0.000000      0.000000
# max     82.000000  445168.000000      16.000000  27828.000000   1980.000000
#
#        hours-per-week
# count      311.000000
# mean        40.048232
# std         11.695364
# min          3.000000
# 25%         40.000000
# 50%         40.000000
# 75%         40.000000
# max         84.000000

# %%
df[df["salary"]==">50K"]
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 8       31           Private   45781       Masters             14
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 11      30         State-gov  141297     Bachelors             13
# ...    ...               ...     ...           ...            ...
# 32539   71                 ?  287372     Doctorate             16
# 32545   39         Local-gov  111499    Assoc-acdm             12
# 32554   53           Private  321865       Masters             14
# 32557   40           Private  154374       HS-grad              9
# 32560   52      Self-emp-inc  287927       HS-grad              9
#
#            marital-status         occupation   relationship  \
# 7      Married-civ-spouse    Exec-managerial        Husband
# ...

# %%
# count married and unmarried in high earners
# (wealthy[wealthy["marital-status"].str.contains("Married")]>wealthy[wealthy["marital-status"].str.contains("Married")]
print(wealthy[wealthy["marital-status"].str.contains("Married")]["age"].count())
print(wealthy[~wealthy["marital-status"].str.contains("Married")]["age"].count())
# Out:
# 6736
# 1105

# %%
# summary stats for weekly work hours

df["hours-per-week"].describe()
# Out:
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000
# Name: hours-per-week, dtype: float64

# %%
# count entries with 99 weekly work hours

df[df['hours-per-week']==99.00].count()
# Out:
# age               85
# workclass         85
# fnlwgt            85
# education         85
# education-num     85
# marital-status    85
# occupation        85
# relationship      85
# race              85
# sex               85
# capital-gain      85
# capital-loss      85
# hours-per-week    85
# native-country    85
# salary            85
# dtype: int64

# %%
wealthy[wealthy['hours-per-week']==99.00].count()
# Out:
# age               25
# workclass         25
# fnlwgt            25
# education         25
# education-num     25
# marital-status    25
# occupation        25
# relationship      25
# race              25
# sex               25
# capital-gain      25
# capital-loss      25
# hours-per-week    25
# native-country    25
# salary            25
# dtype: int64

# %%
df.groupby(["native-country"])['hours-per-week'].describe()
# Out:
#                               count       mean        std   min    25%   50%  \
# native-country
# ?                             583.0  41.512864  12.427774   1.0  40.00  40.0
# Cambodia                       19.0  40.894737   2.514287  40.0  40.00  40.0
# Canada                        121.0  40.404959  13.173571   8.0  35.00  40.0
# China                          75.0  37.786667  11.057947   1.0  37.50  40.0
# Columbia                       59.0  39.067797   8.709615   5.0  40.00  40.0
# Cuba                           95.0  39.157895  10.784461   5.0  40.00  40.0
# Dominican-Republic             70.0  42.471429  11.051554  22.0  40.00  40.0
# Ecuador                        28.0  39.571429  10.235843  22.0  33.00  40.0
# El-Salvador                   106.0  36.792453   9.531619   3.0  35.00  40.0
# England                        90.0  41.833333  14.012234   7.0  40.00  40.0
# France                         29.0  45.068966  14.718625  15.0  40.00  42.0
# ...

# %%
poor = df[df["salary"]=="<=50K"]

# %%
# work hours stats by country for high earners

wealthy.groupby("native-country")["hours-per-week"].describe()
# Out:
#                      count       mean        std   min    25%   50%    75%  \
# native-country
# ?                    146.0  45.547945  10.202827   8.0  40.00  40.0  50.00
# Cambodia               7.0  40.000000   0.000000  40.0  40.00  40.0  40.00
# Canada                39.0  45.641026  12.066673  20.0  40.00  45.0  51.00
# China                 20.0  38.900000  10.125008  10.0  38.00  40.0  41.25
# Columbia               2.0  50.000000   0.000000  50.0  50.00  50.0  50.00
# Cuba                  25.0  42.440000  12.453514  14.0  40.00  40.0  50.00
# Dominican-Republic     2.0  47.000000   9.899495  40.0  43.50  47.0  50.50
# Ecuador                4.0  48.750000   2.500000  45.0  48.75  50.0  50.00
# El-Salvador            9.0  45.000000   7.071068  35.0  40.00  45.0  50.00
# England               30.0  44.533333  11.072592  20.0  40.00  40.0  50.00
# France                12.0  50.750000  16.360290  40.0  40.00  47.5  50.00
# ...

# %%
poor.groupby("native-country")["hours-per-week"].describe()
# Out:
#                               count       mean        std   min    25%   50%  \
# native-country
# ?                             437.0  40.164760  12.817002   1.0  40.00  40.0
# Cambodia                       12.0  41.416667   3.088346  40.0  40.00  40.0
# Canada                         82.0  37.914634  13.012056   8.0  32.75  40.0
# China                          55.0  37.381818  11.439844   1.0  36.00  40.0
# Columbia                       57.0  38.684211   8.610952   5.0  40.00  40.0
# Cuba                           70.0  37.985714   9.960055   5.0  40.00  40.0
# Dominican-Republic             68.0  42.338235  11.121594  22.0  40.00  40.0
# Ecuador                        24.0  38.041667  10.251105  22.0  30.00  40.0
# El-Salvador                    97.0  36.030928   9.396867   3.0  32.00  40.0
# England                        60.0  40.483333  15.177472   7.0  40.00  40.0
# France                         17.0  41.058824  12.401969  15.0  40.00  40.0
# ...
